# %%
import cv2
from PIL import Image
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('validated.csv')

df = df[df.valid == True]

df
# Out:
#                                                   image    x    y  \
# 0     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  299   58
# 1     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  324  300
# 2     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  272  321
# 3     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  364  288
# 9     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  109  178
# ...                                                 ...  ...  ...
# 3733  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  192  160
# 3734  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  331   55
# 3735  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  368   18
# 3736  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  331  102
# 3737  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  136  324
#
#                                                    mask  valid
# 0     /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# ...

# %%
df = df.drop_duplicates(subset=['mask', 'x', 'y'])

df
# Out:
#                                                   image    x    y  \
# 0     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  299   58
# 1     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  324  300
# 2     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  272  321
# 3     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  364  288
# 9     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  109  178
# ...                                                 ...  ...  ...
# 3733  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  192  160
# 3734  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  331   55
# 3735  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  368   18
# 3736  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  331  102
# 3737  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  136  324
#
#                                                    mask  valid
# 0     /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# ...

# %%
df['image_exists'] = df['image'].apply(lambda x: os.path.exists(x))
df['mask_exists'] = df['mask'].apply(lambda x: os.path.exists(x))

# total number of images
print('total images:', len(df))
print('total that exist:', df['image_exists'].sum())

# total number of masks
print('total masks:', len(df))
print('total that exist:', df['mask_exists'].sum())
# Out:
# total images: 2398
# total that exist: 2398
# total masks: 2398
# total that exist: 2398
# /tmp/ipykernel_21993/3611965974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['image_exists'] = df['image'].apply(lambda x: os.path.exists(x))
# /tmp/ipykernel_21993/3611965974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mask_exists'] = df['mask'].apply(lambda x: os.path.exists(x))

# %%
df = pd.read_csv('classified.csv')

df['image_exists'] = df['image'].apply(lambda x: os.path.exists(x))
df['mask_exists'] = df['mask'].apply(lambda x: os.path.exists(x))

# total number of images
print('total images:', len(df))
print('total that exist:', df['image_exists'].sum())

# total number of masks
print('total masks:', len(df))
print('total that exist:', df['mask_exists'].sum())
# Out:
# total images: 2398
# total that exist: 2398
# total masks: 2398
# total that exist: 2398

# %%
df = df.drop_duplicates(subset=['mask', 'x', 'y'])

df
# Out:
#                                                   image    x    y  \
# 0     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  299   58
# 1     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  324  300
# 2     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  272  321
# 3     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  364  288
# 4     /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  109  178
# ...                                                 ...  ...  ...
# 2393  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  192  160
# 2394  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  331   55
# 2395  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  368   18
# 2396  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  331  102
# 2397  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  136  324
#
#                                                    mask lifecycle  \
# 0     /home/jack/Mounts/DiskOne/kona_coffee/masks/10...  ripening
# ...

# %%
df['lifecycle'].value_counts()
# Out:
# unripe      1371
# ripe         532
# ripening     384
# unknown      109
# overripe       2
# Name: lifecycle, dtype: int64
