# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2

df = pd.read_csv('/home/jack/Documents/Workspace/kona_coffee/runs/runs/segment/train2/results.csv')

columns = []
for column in df.columns:
    columns.append(column.strip())
    
df.columns = columns

df
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  \
# 0       1         1.36100          3.9065          3.0942          1.5834
# 1       2         1.43310          3.4110          2.8277          1.6688
# 2       3         1.49050          3.4452          2.6614          1.7076
# 3       4         1.49960          3.4525          2.5342          1.7120
# 4       5         1.55550          3.5422          2.4657          1.7370
# ..    ...             ...             ...             ...             ...
# 62     63         1.07480          2.9481          1.6979          1.4047
# 63     64         1.04090          2.8192          1.6586          1.3785
# 64     65         1.03480          2.7958          1.6149          1.3939
# 65     66         1.03110          2.8266          1.6094          1.3583
# 66     67         0.99967          2.7646          1.6473          1.3412
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# ...

# %%
plt.plot(df['epoch'], df['train/box_loss'])
