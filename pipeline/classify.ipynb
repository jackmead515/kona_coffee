# %%
import cv2
import numpy as np
import pandas as pd
import os

df = pd.read_csv('validated.csv')

df = df.dropna()

df = df[df['valid'] == True]

old_df = None
if os.path.exists('classified.csv'):
    old_df = pd.read_csv('classified.csv')
    
# remove if already classified and image and mask match
if old_df is not None:
    df = df[~df['mask'].isin(old_df['mask'])]

df
# Out:
#                                                   image    x    y  \
# 3065  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  354  182
# 3066  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  329  165
# 3068  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  317  184
# 3070  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  169  171
# 3075  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  239   33
# ...                                                 ...  ...  ...
# 3237  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  365  273
# 3238  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  243  334
# 3239  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  235  267
# 3240  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  138  320
# 3241  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  199  299
#
#                                                    mask  valid
# 3065  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3066  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3068  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3070  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3075  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# ...                                                 ...    ...
# 3237  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3238  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3239  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3240  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
# 3241  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   True
#
# [113 rows x 5 columns]

# %%
cv2.namedWindow('image')
cv2.resizeWindow('image', 800, 640)

states = ['unknown', 'unripe', 'ripening', 'ripe', 'overripe']
selected_class = states[0]
goto_next = False

def get_on_press(class_name):
    def on_press(state, *args, **kwargs):
        global selected_class, goto_next
        selected_class = class_name
        goto_next = True
        return state
    return on_press

for state in states:
    cv2.createButton(state, get_on_press(state), None, cv2.QT_PUSH_BUTTON, 0)


def get_display_image(row):
    cv2image = cv2.imread(row.image)

    mask = np.load(row['mask'])
    mask = mask.astype(np.uint8)
    
    # apply the mask to the image
    mask_image = cv2.bitwise_and(cv2image, cv2image, mask=mask)
    
    # crop the image to the mask
    mask_image = mask_image[np.ix_(mask.any(1),mask.any(0))]
    
    return mask_image


image_index = 0
data = []

show_image = get_display_image(df.iloc[image_index])

while True:
    if show_image is None or show_image.shape[0] <= 0 or show_image.shape[1] <= 0:
        print(f'invalid mask {df.iloc[image_index]["mask"]}')
        image_index += 1
        show_image = get_display_image(df.iloc[image_index])
        continue
        
    cv2.imshow("image", show_image)
    k = cv2.waitKey(50) & 0xFF
    
    # if escape key, exit
    if k == 27:
        break
    
    if goto_next or k == ord('n'):
        goto_next = False
        row = df.iloc[image_index]
        data.append([row.image, row.x, row.y, row['mask'], selected_class])
        image_index += 1
        if image_index >= len(df):
            break

        show_image = get_display_image(df.iloc[image_index])

# close all open windows
cv2.destroyAllWindows()

# %%
df = pd.DataFrame(data, columns=['image', 'x', 'y', 'mask', 'lifecycle'])

if old_df is not None:
    df = pd.concat([old_df, df])

df.to_csv('classified.csv', index=False)

df
# Out:
#                                                  image    x    y  \
# 0    /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  299   58
# 1    /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  324  300
# 2    /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  272  321
# 3    /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  364  288
# 4    /home/jack/Mounts/DiskOne/kona_coffee/splits/1...  109  178
# ..                                                 ...  ...  ...
# 108  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  365  273
# 109  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  243  334
# 110  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  235  267
# 111  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  138  320
# 112  /home/jack/Mounts/DiskOne/kona_coffee/augmente...  199  299
#
#                                                   mask lifecycle
# 0    /home/jack/Mounts/DiskOne/kona_coffee/masks/10...  ripening
# 1    /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   unknown
# 2    /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   unknown
# 3    /home/jack/Mounts/DiskOne/kona_coffee/masks/10...   unknown
# 4    /home/jack/Mounts/DiskOne/kona_coffee/masks/10...      ripe
# ..                                                 ...       ...
# 108  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...    unripe
# 109  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...    unripe
# 110  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...    unripe
# 111  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...    unripe
# 112  /home/jack/Mounts/DiskOne/kona_coffee/masks/10...      ripe
#
# [2107 rows x 5 columns]

# %%
df['lifecycle'].value_counts()
# Out:
# unripe      1221
# ripe         456
# ripening     324
# unknown      104
# overripe       2
# Name: lifecycle, dtype: int64
