# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")

results = model.train(
    batch=8,
    device="cpu",
    data="dataset.yaml",
    epochs=100,
    imgsz=640,
    workers=10,
    seed=42,
    dropout=0.1,
    degrees=180.0,
    flipud=0.5,
    fliplr=0.5,
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.203 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (AMD Ryzen 5 3600 6-Core Processor)
# ...
